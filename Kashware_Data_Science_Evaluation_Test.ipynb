# %% [markdown]
# <a href="https://colab.research.google.com/github/Satkarjain/A-to-Z-Resources-for-Students/blob/master/Kashware_Data_Science_Evaluation_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from requests import get
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import pandas as pd
import re
import re
import time

# %%
offer_details = {}
offer_details['Offer_heading'] = []
offer_details['By '] = []
offer_details['Bank  '] = []
offer_details['Valid Till '] = []
offer_details['Deal Type'] = []
offer_details['Card Type'] = []
offer_details['Segment'] = []
df= pd.DataFrame()
for x in range(1,4):
  url = "https://happycredit.in/kotak-mahindra-bank-offers/?page="+str(x)
  browser =webdriver.Chrome("chromedriver",options=options)
  browser.get(url)
  time.sleep(3)
  html = browser.page_source
  html_soup = BeautifulSoup(html, 'lxml')
  offer_list = html_soup.find_all('a', class_ = "coupon-cart others")
  for offer in offer_list:
    offer_details["Offer_heading"].append(offer.h3.text)
    other_details = offer.find_all('span')
    flag = 0
    for f in other_details:
      a= f.text.split(':')
      if a[0] == "Segment":
        flag =1
      offer_details[a[0]].append(a[1])
    
    if flag == 0:
      offer_details['Segment'].append('Not given')

# %%
pd.DataFrame(offer_details)
# Out:
#                                         Offer_heading  ...                  Segment
# 0   Amazon EMI Offer - 3, 6, 9 & 12 Month EMI on A...  ...                Not given
# 1   Flipkart EMI Offer- 3, 6, 9, 12, 18 and 24 Mon...  ...                Not given
# 2              Avail Easy EMI on shopping on Flipkart  ...                Not given
# 3   Avail Easy EMI & no Processing Fee on Amazon u...  ...                Not given
# 4         Snapdeal EMI Offer - 3, 6, 9 & 12 Month EMI  ...                Not given
# 5   Paytm EMI Offer - 3, 6, 9 & 12 Months EMI on P...  ...                Not given
# 6            Yatra EMI Offer - 3, 6, 9 & 12 Month EMI  ...                Not given
# 7       Bookmyshow EMI Offer - 3, 6, 9 & 12 Month EMI  ...                Not given
# 8   Goibibo EMI Offer - 3, 6, 9 & 12 Month EMI on ...  ...                Not given
# 9   Avail Easy EMI & no Processing Fee on Goibibo ...  ...                Not given
# 10  Avail Easy EMI & no Processing Fee on BookMySh...  ...                Not given
# 11         Flat 21% OFF on prescribed medicine on 1mg  ...                Not given
# 12      Flat 18% OFF on prescription medicines on 1mg  ...                Not given
# 13  Get 15% OFF on Gourmet Passport membership fee...  ...                Not given
# 14  Get Flat Rs. 2500 OFF on International Holiday...  ...   International Holidays
# 15  Get Flat Rs. 1000 OFF on Domestic Holidays on ...  ...        Domestic Holidays
# 16  Get 15% OFF on select category Hotels on EaseM...  ...                Not given
# 17  Get up to Rs. 700 OFF on Domestic Flight Booki...  ...         Domestic Flights
# 18               Flat 20% OFF on medicines on Netmeds  ...                Not given
# 19           Croma EMI Offer - 3, 6, 9 & 12 Month EMI  ...                Not given
# 20  Flat Rs. 150 OFF on purchase of Rs. 400 and ab...  ...                Not given
# 21       Spice Hotspot EMI Offer - 3, 6 & 9 Month EMI  ...                Not given
# 22      Sangeetha Mobiles EMI Offer - 3 & 6 Month EMI  ...                Not given
# 23            ebay EMI Offer - 3, 6, 9 & 12 Month EMI  ...                Not given
#
# [24 rows x 7 columns]
